# %% [markdown]
# <a href="https://colab.research.google.com/github/SusaiIgnesh/Readme/blob/main/analusis_07_09_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
def sum1(num1,num2):
  return num1+num2

# %%
sum1(4,8)
# Out:
# 12

# %%
sum1('varun','adii')
# Out:
# 'varunadii'

# %%
#list
list1 = [545, 567432.345, 'hey', 'bye', True]

# %%
## ORDERED-> once created, ORDER DOES not change
list1
# Out:
# [545, 567432.345, 'hey', 'bye', True]

# %%
#Indexed
list1[0]# first element
# Out:
# 545

# %%
list2 = ['line', 'plot', list1]
list2
# Out:
# ['line', 'plot', [545, 567432.345, 'hey', 'bye', True]]

# %%
list2[-1]
# Out:
# [545, 567432.345, 'hey', 'bye', True]

# %%
list4 = [3,4,1,1,2,2, 'xxx', 56867, True, 'yyy', 'milk']
# List is ORDERED, INDEXED
set1 = set(list4)
set1
# Out:
# {1, 2, 3, 4, 56867, 'milk', 'xxx', 'yyy'}

# %%
# INDEXING-> undefined 
set1[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-2d2113d7d672> in <module>
#       1 # INDEXING-> undefined
# ----> 2 set1[2]
#
# TypeError: 'set' object is not subscriptable

# %%
set2 = {list1} # an ordered, indexed collection CANNOT become a part of UNORDERED,
# unindexed collection!!!!
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-61b288fb498b> in <module>
# ----> 1 set2 = {list1} # an ordered, indexed collection CANNOT become a part of UNORDERED,
#       2 # unindexed collection!!!!
#
# TypeError: unhashable type: 'list'

# %%
set2 = {set1, 'op'}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-d04eab793fb9> in <module>
# ----> 1 set2 = {set1, 'op'}
#
# TypeError: unhashable type: 'set'

# %%
tup = (3435,464,56885875)
tup
# Out:
# (3435, 464, 56885875)

# %%
del tup[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-e5558afa55a9> in <module>
# ----> 1 del tup[1]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
tup[0] = 3435
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-23322574c07a> in <module>
# ----> 1 tup[0] = 3435
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Functions can return multiple values!
def division(num1,num2):
  result = int(num1/num2) # TYPE CASTE
  res = num1%num2
  return result,res # returning 2 independent units

num1,num2 = division(60,2)
print(num1,num2)
# Out:
# 30 0

# %%
df1 = lambda x: x+273
df1(345)
# Out:
# 618

# %%
y = lambda m,x,c: m*x + c
y(23,45,56.77)
# Out:
# 1091.77

# %%
for i in [5]:
  print(i)
# Out:
# 5

# %%
for i in list1:
  print(i)
# Out:
# 545
# 567432.345
# hey
# bye
# True

# %%
counter = len(list1) -1
while(counter>=0):
  print(list1[counter])
  counter = counter - 1
# Out:
# True
# bye
# hey
# 567432.345
# 545

# %%
class myclass:
  def whatever(): #this function will NOT be a part of my classes
    return 'hey hey'
  def whatevr2(this): # this function will be a part of my class
    return 'me i'

# %%
obj = myclass() # new objects 
print(obj.whatever()) # this should work
print(obj.whatevr2()) # this should be an error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-98401e9eedec> in <module>
#       1 obj = myclass() # new objects
# ----> 2 print(obj.whatever()) # this should work
#       3 print(obj.whatevr2()) # this should be an error
#
# TypeError: whatever() takes 0 positional arguments but 1 was given

# %%
df=pd.read_csv('/content/breastcancer_data.csv')
df
# Out:
#             id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0       842302         M        17.99         10.38          122.80
# 1       842517         M        20.57         17.77          132.90
# 2     84300903         M        19.69         21.25          130.00
# 3     84348301         M        11.42         20.38           77.58
# 4     84358402         M        20.29         14.34          135.10
# ...        ...       ...          ...           ...             ...
# 1133     93316         M        21.56         22.39          142.00
# 1134     93317         M        20.13         28.25          131.20
# 1135     93318         M        16.60         28.08          108.30
# 1136     93319         M        20.60         29.33          140.10
# 1137     93320         B         7.76         24.54           47.92
#
#       area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0        1001.0          0.11840           0.27760         0.30010
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1138 entries, 0 to 1137
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1138 non-null   int64
#  1   diagnosis               1138 non-null   object
#  2   radius_mean             1138 non-null   float64
#  3   texture_mean            1138 non-null   float64
#  4   perimeter_mean          1138 non-null   float64
#  5   area_mean               1138 non-null   float64
#  6   smoothness_mean         1138 non-null   float64
#  7   compactness_mean        1138 non-null   float64
#  8   concavity_mean          1138 non-null   float64
#  9   symmetry_mean           1138 non-null   float64
#  10  fractal_dimension_mean  1138 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 97.9+ KB

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  1.138000e+03  1138.000000   1138.000000     1138.000000  1138.000000
# mean   1.523243e+07    14.127292     19.289649       91.969033   654.889104
# std    8.965268e+07     3.522499      4.299144       24.288293   351.759340
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    9.299525e+04    11.700000     16.170000       75.170000   420.300000
# 50%    9.327950e+04    13.370000     18.840000       86.240000   551.100000
# 75%    9.060125e+05    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  symmetry_mean  \
# count      1138.000000       1138.000000     1138.000000    1138.000000
# mean          0.096360          0.104341        0.088799       0.181162
# ...

# %%
df.isna()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0     False      False        False         False           False      False
# 1     False      False        False         False           False      False
# 2     False      False        False         False           False      False
# 3     False      False        False         False           False      False
# 4     False      False        False         False           False      False
# ...     ...        ...          ...           ...             ...        ...
# 1133  False      False        False         False           False      False
# 1134  False      False        False         False           False      False
# 1135  False      False        False         False           False      False
# 1136  False      False        False         False           False      False
# 1137  False      False        False         False           False      False
#
# ...

# %%
df.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# id                        1.523243e+07
# radius_mean               1.412729e+01
# texture_mean              1.928965e+01
# perimeter_mean            9.196903e+01
# area_mean                 6.548891e+02
# smoothness_mean           9.636028e-02
# compactness_mean          1.043410e-01
# concavity_mean            8.879932e-02
# symmetry_mean             1.811619e-01
# fractal_dimension_mean    6.279761e-02
# dtype: float64

# %%
df.nunique()
# Out:
# diagnosis                   2
# radius_mean               456
# texture_mean              479
# perimeter_mean            522
# area_mean                 539
# smoothness_mean           474
# compactness_mean          537
# concavity_mean            537
# symmetry_mean             432
# fractal_dimension_mean    499
# dtype: int64

# %%
df.drop('id',axis=1,inplace=True)

# %%
df
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0            M        17.99         10.38          122.80     1001.0
# 1            M        20.57         17.77          132.90     1326.0
# 2            M        19.69         21.25          130.00     1203.0
# 3            M        11.42         20.38           77.58      386.1
# 4            M        20.29         14.34          135.10     1297.0
# ...        ...          ...           ...             ...        ...
# 1133         M        21.56         22.39          142.00     1479.0
# 1134         M        20.13         28.25          131.20     1261.0
# 1135         M        16.60         28.08          108.30      858.1
# 1136         M        20.60         29.33          140.10     1265.0
# 1137         B         7.76         24.54           47.92      181.0
#
#       smoothness_mean  compactness_mean  concavity_mean  symmetry_mean  \
# ...

# %%
df['diagnosis'].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
sns.countplot(df['diagnosis'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.histplot(df['area_mean'],color='blue')

# %%
plt.figure(figsize=(10,3))
sns.histplot(df['radius_mean'],color='red')

# %%
sns.histplot(df['perimeter_mean'],color='yellow')

# %%
sns.distplot(df['smoothness_mean'],color='green')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['radius_mean'],color='green')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['texture_mean'],color='green')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['perimeter_mean'],color='green')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['area_mean'],color='green')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['smoothness_mean'],color='green')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['compactness_mean'],color='green')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['concavity_mean'],color='green')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['symmetry_mean'],color='green')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['fractal_dimension_mean'],color='green')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Boxplot to check the presence of outliers
fig, axes = plt.subplots(3, 3, figsize = (15, 12))
sns.boxplot(data = df, y = 'radius_mean', ax = axes[0,0])
sns.boxplot(data = df, y = 'texture_mean', ax = axes[0,1])
sns.boxplot(data = df, y = 'perimeter_mean', ax = axes[0,2])
sns.boxplot(data = df, y = 'area_mean', ax = axes[1,0])
sns.boxplot(data = df, y = 'smoothness_mean', ax = axes[1, 1])
sns.boxplot(data = df, y = 'compactness_mean', ax = axes[1,2])
sns.boxplot(data = df, y = 'concavity_mean', ax = axes[2,0])
sns.boxplot(data = df, y = 'symmetry_mean', ax = axes[2, 1])
sns.boxplot(data = df, y = 'fractal_dimension_mean', ax = axes[2,2]);

# %%
sns.scatterplot(data=df, x='area_mean', y='concavity_mean',color='red')

# %%
sns.violinplot(data=df, x='diagnosis', y='radius_mean')

# %%
sns.violinplot(data=df, x='diagnosis', y='symmetry_mean')

# %%
sns.heatmap(df.corr(),cmap='coolwarm',annot=True)

# %%
df.corr()
# Out:
#                         radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean                1.000000      0.323782        0.997855   0.987357
# texture_mean               0.323782      1.000000        0.329533   0.321086
# perimeter_mean             0.997855      0.329533        1.000000   0.986507
# area_mean                  0.987357      0.321086        0.986507   1.000000
# smoothness_mean            0.170581     -0.023389        0.207278   0.177028
# compactness_mean           0.506124      0.236702        0.556936   0.498502
# concavity_mean             0.676764      0.302418        0.716136   0.685983
# symmetry_mean              0.147741      0.071401        0.183027   0.151293
# fractal_dimension_mean    -0.311631     -0.076437       -0.261477  -0.283110
#
#                         smoothness_mean  compactness_mean  concavity_mean  \
# radius_mean                    0.170581          0.506124        0.676764
# ...

# %%
sns.pairplot(df)
