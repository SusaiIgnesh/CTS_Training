# %% [markdown]
# <a href="https://colab.research.google.com/github/SusaiIgnesh/Readme/blob/main/Frequency_distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **House_Rent Dataset**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('/content/House_Rent_Dataset.csv')

# %%
df.head(4)
# Out:
#     Posted On  BHK   Rent  Size            Floor   Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2  Super Area
# 1  2022-05-13    2  20000   800       1 out of 3  Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3  Super Area
# 3  2022-07-04    2  10000   800       1 out of 2  Super Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   object
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   object
#  5   Area Type          4746 non-null   object
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 445.1+ KB

# %%
df.describe()
# Out:
#                BHK          Rent         Size     Bathroom
# count  4746.000000  4.746000e+03  4746.000000  4746.000000
# mean      2.083860  3.499345e+04   967.490729     1.965866
# std       0.832256  7.810641e+04   634.202328     0.884532
# min       1.000000  1.200000e+03    10.000000     1.000000
# 25%       2.000000  1.000000e+04   550.000000     1.000000
# 50%       2.000000  1.600000e+04   850.000000     2.000000
# 75%       3.000000  3.300000e+04  1200.000000     2.000000
# max       6.000000  3.500000e+06  8000.000000    10.000000

# %%
df.isna()
# Out:
#       Posted On    BHK   Rent   Size  Floor  Area Type  Area Locality   City  \
# 0         False  False  False  False  False      False          False  False
# 1         False  False  False  False  False      False          False  False
# 2         False  False  False  False  False      False          False  False
# 3         False  False  False  False  False      False          False  False
# 4         False  False  False  False  False      False          False  False
# ...         ...    ...    ...    ...    ...        ...            ...    ...
# 4741      False  False  False  False  False      False          False  False
# 4742      False  False  False  False  False      False          False  False
# 4743      False  False  False  False  False      False          False  False
# 4744      False  False  False  False  False      False          False  False
# 4745      False  False  False  False  False      False          False  False
#
# ...

# %%
df.nunique()
# Out:
# Posted On              81
# BHK                     6
# Rent                  243
# Size                  615
# Floor                 480
# Area Type               3
# Area Locality        2235
# City                    6
# Furnishing Status       3
# Tenant Preferred        3
# Bathroom                8
# Point of Contact        3
# dtype: int64

# %%
df['BHK'].plot(kind='hist');

# %%
df['Bathroom'].plot(kind='hist');

# %%
sns.countplot(df['BHK'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(df['City'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(df['Bathroom'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(df['Tenant Preferred'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(data=df,x='BHK',hue='Bathroom')

# %%
sns.countplot(data=df,x='BHK',hue='Tenant Preferred')

# %%
sns.countplot(data=df,x='BHK',hue='City')

# %%
sns.countplot(data=df,x='BHK',hue='Furnishing Status')

# %%
sns.distplot(df['Rent'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Size'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['BHK'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Bathroom'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.pairplot(df)

# %%
df1 = pd.crosstab(index=df['BHK'], columns = 'Frequency')

# %%
df1
# Out:
# col_0  Frequency
# BHK
# 1           1167
# 2           2265
# 3           1098
# 4            189
# 5             19
# 6              8

# %%
df1['percent']=df1['Frequency']/df1['Frequency'].sum()*100
df1
# Out:
# col_0  Frequency    percent
# BHK
# 1           1167  24.589128
# 2           2265  47.724399
# 3           1098  23.135272
# 4            189   3.982301
# 5             19   0.400337
# 6              8   0.168563

# %%
df1 = pd.crosstab(index=df['Area Type'], columns = 'Frequency')

# %%
df1
# Out:
# col_0        Frequency
# Area Type
# Built Area           2
# Carpet Area       2298
# Super Area        2446

# %%
df1['percent']=df1['Frequency']/df1['Frequency'].sum()*100
df1
# Out:
# col_0        Frequency    percent
# Area Type
# Built Area           2   0.042141
# Carpet Area       2298  48.419722
# Super Area        2446  51.538137

# %%
df1 = pd.crosstab(index=df['City'], columns = 'Frequency')

# %%
df1
# Out:
# col_0      Frequency
# City
# Bangalore        886
# Chennai          891
# Delhi            605
# Hyderabad        868
# Kolkata          524
# Mumbai           972

# %%
df1['percent']=df1['Frequency']/df1['Frequency'].sum()*100
df1
# Out:
# col_0      Frequency    percent
# City
# Bangalore        886  18.668352
# Chennai          891  18.773704
# Delhi            605  12.747577
# Hyderabad        868  18.289086
# Kolkata          524  11.040877
# Mumbai           972  20.480405

# %%
df1 = pd.crosstab(index=df['Furnishing Status'], columns = 'Frequency')
df1
# Out:
# col_0              Frequency
# Furnishing Status
# Furnished                680
# Semi-Furnished          2251
# Unfurnished             1815

# %%
df1['percent']=df1['Frequency']/df1['Frequency'].sum()*100
df1
# Out:
# col_0              Frequency    percent
# Furnishing Status
# Furnished                680  14.327855
# Semi-Furnished          2251  47.429414
# Unfurnished             1815  38.242731

# %%
df1 = pd.crosstab(index=df['Tenant Preferred'], columns = 'Frequency')
df1
# Out:
# col_0             Frequency
# Tenant Preferred
# Bachelors               830
# Bachelors/Family       3444
# Family                  472

# %%
df1['percent']=df1['Frequency']/df1['Frequency'].sum()*100
df1
# Out:
# col_0             Frequency    percent
# Tenant Preferred
# Bachelors               830  17.488411
# Bachelors/Family       3444  72.566372
# Family                  472   9.945217

# %%
df1 = pd.crosstab(index=df['Bathroom'], columns = 'Frequency')
df1
# Out:
# col_0     Frequency
# Bathroom
# 1              1474
# 2              2291
# 3               749
# 4               156
# 5                60
# 6                12
# 7                 3
# 10                1

# %%
df1['percent']=df1['Frequency']/df1['Frequency'].sum()*100
df1
# Out:
# col_0     Frequency    percent
# Bathroom
# 1              1474  31.057733
# 2              2291  48.272229
# 3               749  15.781711
# 4               156   3.286979
# 5                60   1.264223
# 6                12   0.252845
# 7                 3   0.063211
# 10                1   0.021070

# %%
df1 = pd.crosstab(index=df['Point of Contact'], columns = 'Frequency')
df1
# Out:
# col_0             Frequency
# Point of Contact
# Contact Agent          1529
# Contact Builder           1
# Contact Owner          3216

# %%
df1['percent']=df1['Frequency']/df1['Frequency'].sum()*100
df1
# Out:
# col_0             Frequency    percent
# Point of Contact
# Contact Agent          1529  32.216603
# Contact Builder           1   0.021070
# Contact Owner          3216  67.762326
